# %%
import numpy as np
x=np.array(
[
[1,9,2],
[0,1,1],
[4,1,0],
]
)

print x

x.diagonal()
# Out:
# [[1 9 2]
#  [0 1 1]
#  [4 1 0]]
# array([1, 1, 0])

# %%
from pprint import pprint
from collections import defaultdict
class DataSet(defaultdict):
    def __init__(self, name=None, keyo=None):
        self.name = name
        self.keyo = keyo or []
        self.keyo_ins = []
        self.env = self.__class__()
    
    def put(self, k, v):
        if k not in env and k not in self.__dict__:
            self.keyo_ins.append(k)
            self.env[k] = True
            self[k] = v
        else:
            raise Exception('dissonance')

    def pprint(self, keyo=None):
        keyo = keyo or self.keyo_ins
        self.pr(k)
        for k in keyo:
            v = self.env.get(k)
            print pprint(data)
    
    def pr(self, label):
        print '\n%s.%s%s\n' % (
             self.name, label,
             len(label)*'=')        
        
    def __getitem__(self, k):
        if k not in self.__dict__:
            return self.get(k)
        
    def __setitem__(self, k, v):
        self.put(k,v)

# %%
ds = DataSet()
ds.x = x

ds.pprint()

def pbj(x):
    return np.tril(
        x+
        (np.tri(
            *x.shape, k=-1, dtype=bool
            ).transpose() * x).transpose())

ds.x_fold=pbj(x)



ds.y=np.array([
[1,0,1],
[0,2,0],
[0,0,3],
]
)

ds.y_fold = pbj(y)
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">RuntimeError</span>                              Traceback (most recent call last)
# <span class="ansigreen">/media/walrus/tools/ipython/ipython/docs/&lt;ipython-input-7-314418580727&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>ds <span class="ansiyellow">=</span> DataSet<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> ds<span class="ansiyellow">.</span>x <span class="ansiyellow">=</span> x<span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> <span class="ansiyellow"></span>
# ...
